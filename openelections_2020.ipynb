# %%
# Plot (presidential - senator race)  VS. senator race percentage 
# All available counties
import glob
from utils.charting import plot_president_vs_senator_per_county

county_folder_list = glob.glob(
    './election_reporting_com/2020/mi/*/'
)

state_abbreviation = 'MI'
fig_counter_base = 100
print('test: ', county_folder_list)
for county_folder in county_folder_list:
    county = county_folder.split('/')[-2]
    plot_president_vs_senator_per_county(county, fig_counter_base)
    fig_counter_base += 100
# Out:
# test:  ['./election_reporting_com/2020/mi/saginaw/', './election_reporting_com/2020/mi/kent/', './election_reporting_com/2020/mi/city_of_detroit/']
# > <ipython-input-35-87d1b650833f>(19)plot_president_vs_senator_per_county()
#      17         return None
#      18     pdb.set_trace()
# ---> 19     for x, y in zip(df_dict_keys, file_list):
#      20         df_dict[x] = pd.read_csv(y)
#      21         if 'party' in y:
#
# ipdb> file_list
# ['./election_reporting_com/2020/mi/kent/kent_county_straight_party_cleaned.csv', './election_reporting_com/2020/mi/kent/kent_county_president_cleaned.csv', './election_reporting_com/2020/mi/kent/kent_county_senator_cleaned.csv']
# ipdb> c
# > <ipython-input-35-87d1b650833f>(19)plot_president_vs_senator_per_county()
#      17         return None
#      18     pdb.set_trace()
# ---> 19     for x, y in zip(df_dict_keys, file_list):
#      20         df_dict[x] = pd.read_csv(y)
#      21         if 'party' in y:
#
# ipdb> c
